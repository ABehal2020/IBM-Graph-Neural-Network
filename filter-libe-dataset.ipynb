# %%
import pandas as pd
import json

df = pd.read_json("libe.json")

# %%
df["Keep"] = True
df["Number of non hydrogen atoms"] = None

# %%
df.head()
# Out:
#    molecule_id                                              bonds  charge  \
# 0  libe-136123  [[0, 2], [1, 3], [1, 4], [2, 7], [2, 5], [2, 6...      -1
# 1  libe-136151  [[0, 1], [1, 3], [1, 2], [3, 4], [4, 6], [4, 5...      -1
# 2  libe-136361  [[0, 1], [0, 2], [1, 3], [1, 4], [2, 6], [2, 5...      -1
# 3  libe-136385  [[0, 6], [0, 1], [0, 3], [0, 2], [1, 7], [1, 4...      -1
# 4  libe-137196  [[0, 4], [1, 6], [1, 4], [2, 6], [2, 5], [3, 6...      -1
#
#   chemical_system                               composition      elements  \
# 0         C-F-H-O  {'O': 3.0, 'C': 3.0, 'H': 3.0, 'F': 1.0}  [C, F, H, O]
# 1         C-F-H-O  {'O': 3.0, 'C': 3.0, 'F': 1.0, 'H': 3.0}  [C, F, H, O]
# 2         C-F-H-O  {'O': 3.0, 'C': 3.0, 'H': 3.0, 'F': 1.0}  [C, F, H, O]
# 3         C-F-H-O  {'C': 3.0, 'F': 1.0, 'H': 3.0, 'O': 3.0}  [C, F, H, O]
# 4         C-F-H-O  {'H': 3.0, 'O': 3.0, 'C': 3.0, 'F': 1.0}  [C, F, H, O]
#
# ...

# %%
df.tail()
# Out:
#        molecule_id                                              bonds  charge  \
# 17185  libe-658720           [[0, 1], [0, 2], [2, 4], [2, 3], [3, 5]]       1
# 17186  libe-658717           [[0, 1], [0, 2], [1, 5], [2, 4], [2, 3]]       1
# 17187  libe-658736           [[0, 1], [0, 2], [2, 4], [2, 3], [3, 5]]       1
# 17188  libe-652605  [[0, 1], [0, 11], [1, 2], [1, 3], [2, 10], [3,...      -1
# 17189  libe-652486  [[0, 1], [0, 11], [1, 2], [1, 3], [2, 10], [3,...       0
#
#       chemical_system                                composition  \
# 17185           C-H-O             {'C': 2.0, 'O': 3.0, 'H': 1.0}
# 17186           C-H-O             {'C': 2.0, 'O': 3.0, 'H': 1.0}
# 17187           C-H-O             {'C': 2.0, 'O': 3.0, 'H': 1.0}
# 17188        C-H-Li-O  {'O': 6.0, 'C': 4.0, 'Li': 2.0, 'H': 4.0}
# 17189        C-H-Li-O  {'O': 6.0, 'C': 4.0, 'Li': 2.0, 'H': 4.0}
#
#             elements formula_alphabetical  \
# 17185      [C, H, O]             C2 H1 O3
# ...

# %%
# loop over all rows in data frame specifically looking at the composition column
# if any element is heavier than Calcium, throw this row out
# also keep a counter for the number of atoms in the molecule corresponding to the row you are looking at
# however, do not increment the counter if the value corresponds to the number of hydrogen atoms
# throw out the row if the counter is greater than 10

print(len(df))
# Out:
# 17190

# %%
# first 20 elements of the periodic table
validElements = ["H", "He", "Li", "Be", "B", "C", "N", "O", "F", "Ne", "Na", "Mg", "Al", "Si", "P", "S", "Cl", "Ar", "K", "Ca"]

print(len(validElements))
# Out:
# 20

# %%
for i in range(len(df)):
    composition = dict(df.loc[i]["composition"])
    # number of atoms that are not hydrogen
    numAtoms = 0
    for key in composition:
        if key not in validElements:
            df.at[i, "Keep"] = False
        if key != "H":
            numAtoms += (int)(composition[key])
    df.at[i, "Number of non hydrogen atoms"] = numAtoms
    if numAtoms > 10:
        df.at[i, "Keep"] = False

# %%
df.head()
# Out:
#    molecule_id                                              bonds  charge  \
# 0  libe-136123  [[0, 2], [1, 3], [1, 4], [2, 7], [2, 5], [2, 6...      -1
# 1  libe-136151  [[0, 1], [1, 3], [1, 2], [3, 4], [4, 6], [4, 5...      -1
# 2  libe-136361  [[0, 1], [0, 2], [1, 3], [1, 4], [2, 6], [2, 5...      -1
# 3  libe-136385  [[0, 6], [0, 1], [0, 3], [0, 2], [1, 7], [1, 4...      -1
# 4  libe-137196  [[0, 4], [1, 6], [1, 4], [2, 6], [2, 5], [3, 6...      -1
#
#   chemical_system                               composition      elements  \
# 0         C-F-H-O  {'O': 3.0, 'C': 3.0, 'H': 3.0, 'F': 1.0}  [C, F, H, O]
# 1         C-F-H-O  {'O': 3.0, 'C': 3.0, 'F': 1.0, 'H': 3.0}  [C, F, H, O]
# 2         C-F-H-O  {'O': 3.0, 'C': 3.0, 'H': 3.0, 'F': 1.0}  [C, F, H, O]
# 3         C-F-H-O  {'C': 3.0, 'F': 1.0, 'H': 3.0, 'O': 3.0}  [C, F, H, O]
# 4         C-F-H-O  {'H': 3.0, 'O': 3.0, 'C': 3.0, 'F': 1.0}  [C, F, H, O]
#
# ...

# %%
df.tail()
# Out:
#        molecule_id                                              bonds  charge  \
# 17185  libe-658720           [[0, 1], [0, 2], [2, 4], [2, 3], [3, 5]]       1
# 17186  libe-658717           [[0, 1], [0, 2], [1, 5], [2, 4], [2, 3]]       1
# 17187  libe-658736           [[0, 1], [0, 2], [2, 4], [2, 3], [3, 5]]       1
# 17188  libe-652605  [[0, 1], [0, 11], [1, 2], [1, 3], [2, 10], [3,...      -1
# 17189  libe-652486  [[0, 1], [0, 11], [1, 2], [1, 3], [2, 10], [3,...       0
#
#       chemical_system                                composition  \
# 17185           C-H-O             {'C': 2.0, 'O': 3.0, 'H': 1.0}
# 17186           C-H-O             {'C': 2.0, 'O': 3.0, 'H': 1.0}
# 17187           C-H-O             {'C': 2.0, 'O': 3.0, 'H': 1.0}
# 17188        C-H-Li-O  {'O': 6.0, 'C': 4.0, 'Li': 2.0, 'H': 4.0}
# 17189        C-H-Li-O  {'O': 6.0, 'C': 4.0, 'Li': 2.0, 'H': 4.0}
#
#             elements formula_alphabetical  \
# 17185      [C, H, O]             C2 H1 O3
# ...

# %%
print(len(df.loc[df["Keep"] == True]))
# Out:
# 14361

# %%
print(len(df.loc[df["Keep"] == False]))
# Out:
# 2829

# %%
# rows we want to keep
df2 = df.loc[df["Keep"] == True]

# %%
df2.head()
# Out:
#    molecule_id                                              bonds  charge  \
# 0  libe-136123  [[0, 2], [1, 3], [1, 4], [2, 7], [2, 5], [2, 6...      -1
# 1  libe-136151  [[0, 1], [1, 3], [1, 2], [3, 4], [4, 6], [4, 5...      -1
# 2  libe-136361  [[0, 1], [0, 2], [1, 3], [1, 4], [2, 6], [2, 5...      -1
# 3  libe-136385  [[0, 6], [0, 1], [0, 3], [0, 2], [1, 7], [1, 4...      -1
# 4  libe-137196  [[0, 4], [1, 6], [1, 4], [2, 6], [2, 5], [3, 6...      -1
#
#   chemical_system                               composition      elements  \
# 0         C-F-H-O  {'O': 3.0, 'C': 3.0, 'H': 3.0, 'F': 1.0}  [C, F, H, O]
# 1         C-F-H-O  {'O': 3.0, 'C': 3.0, 'F': 1.0, 'H': 3.0}  [C, F, H, O]
# 2         C-F-H-O  {'O': 3.0, 'C': 3.0, 'H': 3.0, 'F': 1.0}  [C, F, H, O]
# 3         C-F-H-O  {'C': 3.0, 'F': 1.0, 'H': 3.0, 'O': 3.0}  [C, F, H, O]
# 4         C-F-H-O  {'H': 3.0, 'O': 3.0, 'C': 3.0, 'F': 1.0}  [C, F, H, O]
#
# ...

# %%
df2.tail()
# Out:
#        molecule_id                                     bonds  charge  \
# 17183  libe-658722  [[0, 2], [0, 1], [2, 4], [2, 3], [3, 5]]      -1
# 17184  libe-658723  [[0, 1], [0, 2], [2, 4], [2, 3], [3, 5]]       0
# 17185  libe-658720  [[0, 1], [0, 2], [2, 4], [2, 3], [3, 5]]       1
# 17186  libe-658717  [[0, 1], [0, 2], [1, 5], [2, 4], [2, 3]]       1
# 17187  libe-658736  [[0, 1], [0, 2], [2, 4], [2, 3], [3, 5]]       1
#
#       chemical_system                     composition   elements  \
# 17183           C-H-O  {'C': 2.0, 'O': 3.0, 'H': 1.0}  [C, H, O]
# 17184           C-H-O  {'C': 2.0, 'O': 3.0, 'H': 1.0}  [C, H, O]
# 17185           C-H-O  {'C': 2.0, 'O': 3.0, 'H': 1.0}  [C, H, O]
# 17186           C-H-O  {'C': 2.0, 'O': 3.0, 'H': 1.0}  [C, H, O]
# 17187           C-H-O  {'C': 2.0, 'O': 3.0, 'H': 1.0}  [C, H, O]
#
#       formula_alphabetical                                           molecule  \
# ...

# %%
# rows we don't want to keep
df3 = df.loc[df["Keep"] == False]

# %%
df3.head()
# Out:
#      molecule_id                                              bonds  charge  \
# 103  libe-631212  [[0, 1], [0, 5], [0, 12], [1, 6], [2, 3], [2, ...      -1
# 104  libe-631213  [[0, 5], [0, 1], [1, 6], [2, 3], [2, 6], [3, 4...      -1
# 105  libe-631270  [[0, 5], [0, 1], [0, 13], [1, 14], [2, 3], [2,...      -1
# 106  libe-631277  [[0, 5], [0, 1], [1, 6], [1, 11], [2, 6], [2, ...      -1
# 107  libe-631318  [[0, 1], [0, 5], [0, 12], [1, 6], [2, 3], [2, ...      -1
#
#     chemical_system                                composition       elements  \
# 103        C-H-Li-O  {'Li': 2.0, 'O': 5.0, 'C': 4.0, 'H': 4.0}  [C, H, Li, O]
# 104        C-H-Li-O  {'Li': 2.0, 'O': 5.0, 'C': 4.0, 'H': 4.0}  [C, H, Li, O]
# 105        C-H-Li-O  {'Li': 2.0, 'O': 5.0, 'C': 4.0, 'H': 4.0}  [C, H, Li, O]
# 106        C-H-Li-O  {'Li': 2.0, 'O': 5.0, 'C': 4.0, 'H': 4.0}  [C, H, Li, O]
# 107        C-H-Li-O  {'Li': 2.0, 'O': 5.0, 'C': 4.0, 'H': 4.0}  [C, H, Li, O]
#
# ...

# %%
df3.tail()
# Out:
#        molecule_id                                              bonds  charge  \
# 17068  libe-223775  [[0, 1], [1, 3], [1, 2], [3, 4], [4, 11], [4, ...       1
# 17146  libe-652592  [[0, 11], [0, 1], [0, 16], [1, 2], [1, 3], [2,...       1
# 17147  libe-652576  [[0, 1], [0, 10], [1, 2], [1, 3], [3, 4], [3, ...      -1
# 17188  libe-652605  [[0, 1], [0, 11], [1, 2], [1, 3], [2, 10], [3,...      -1
# 17189  libe-652486  [[0, 1], [0, 11], [1, 2], [1, 3], [2, 10], [3,...       0
#
#       chemical_system                                        composition  \
# 17068      C-F-H-Li-O  {'O': 6.0, 'C': 4.0, 'Li': 1.0, 'F': 1.0, 'H':...
# 17146        C-H-Li-O          {'O': 6.0, 'C': 4.0, 'Li': 3.0, 'H': 4.0}
# 17147        C-H-Li-O          {'O': 6.0, 'C': 4.0, 'Li': 1.0, 'H': 4.0}
# 17188        C-H-Li-O          {'O': 6.0, 'C': 4.0, 'Li': 2.0, 'H': 4.0}
# 17189        C-H-Li-O          {'O': 6.0, 'C': 4.0, 'Li': 2.0, 'H': 4.0}
#
#                elements formula_alphabetical  \
# ...

# %%
df2.to_json("filtered-libe.json")
